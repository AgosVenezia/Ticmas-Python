# %% [markdown]
# ### WorkShop: Árbol de Decisión modelo de Clasificación en Scikit-Learn
#
# **Resolución**: EDA (Análisis Exploratorio de Datos)

# %%
#Punto 1)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#df = pd.read_csv("D:/Documentos/Practica/2023/argentinaPrograma/Python/Modulo 5/Titanic.csv", sep = ",")
df = pd.read_csv("F:/Descargas/Cursos/VSC_PROYECTOS/TicmasPython/Ticmas/Mod5.2.3 TITANIC.csv", sep = ",")

# %%
#Punto 2)

        ###Completar

# %%
#Punto 3)

        ###Completar

# %%
#Punto 4)

        ###Completar

# %%
#Punto 5)

        ###Completar

# %%
#Punto 6)

        ###Completar

# %%
#Punto 7)

        ###Completar

# %%
#Punto 8)

        ###Completar

# %% [markdown]
# **Resolución**: Machine Learning - Modelo de Clasificación

# %%
#Punto 9)

        ###Completar

# %%
#Punto 10)

        ###Completar

# %%
#Punto 11)

        ###Completar

# %%
#Punto 12)

        ###Completar

# %%
#Punto 13)

        ###Completar

# %%
#Punto 14)

        ###Completar

# %%
#Punto 15)

        ###Completar
